# %% [markdown]
# # Launchpad: Welcome, Course Setup, and Colab Orientation
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_predictive_analytics_QM474/main/notebooks/figures/mgmt_474_ai_logo_02-modified.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>QM47400 Predictive Analytics</center>
# # <center>Professor: Davi Moreira </center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_predictive_analytics_QM474/blob/main/notebooks/nb00_launchpad_course_setup_student.ipynb)
#
# ---

# %% [markdown]
# > **📋 Participation Reminder:** This notebook contains **1 PAUSE-AND-DO exercise**. You are expected to complete the exercise before submitting your notebook.
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Navigate Google Colab: run cells, save notebooks, and restart runtimes
# 2. Use Google Gemini responsibly following the Ask → Verify → Document pattern
# 3. Understand the course structure and weekly rhythm
# 4. Find your project group in Brightspace and reach your teammates
# 5. Verify that your Colab environment is properly configured
# 6. Know the notebook conventions used throughout the course
#
# ---

# %% [markdown]
# ## 1. Welcome and Introductions
#
# ### 1.1 Your Instructor: Professor Davi Moreira
#
# <center>
# <div>
#
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_predictive_analytics_QM474/main/notebooks/figures/davi_moreira_photo.JPG" width="200" align="center" style="margin-bottom: 10px;">
#
# </div>
# </center>
#
# **[Professor Davi Moreira](https://davi-moreira.github.io/)** is a Clinical Assistant Professor at Purdue University's Daniels School of Business. His research and teaching interests focus on applied Data Science, Text as Data, NLP, Predictive Analytics, Artificial Intelligence, and Pedagogy.
#
# **Why this course matters:** In today's data-driven business environment, the ability to build, evaluate, and deploy predictive models is essential. Whether you're working in marketing, finance, operations, or strategy, predictive analytics helps you make better decisions, optimize processes, and create competitive advantages.
#
# **What makes this course different:**
# - **Hands-on from day one:** Every concept is immediately applied in Google Colab notebooks
# - **Real business cases:** We use industry-relevant datasets and scenarios
# - **AI-assisted learning:** You'll learn to use Google Gemini responsibly as a coding partner
# - **End-to-end workflow:** From raw data to deployed model to business recommendation
#
# <br clear="all">
#
# ---

# %% [markdown]
# ### 📝 PAUSE-AND-DO Exercise 1 (5 minutes)
#
# Please introduce yourself by answering these questions in a new chunk:
#
# 1. **Name and background.** What is your name? Is there something special about your background you would like to share?
#
# 2. **Statistical and prediction knowledge.** On a scale of 1 to 5, how comfortable are you with introductory statistics (descriptive statistics, probability, hypothesis testing, simple linear regression)? Have you ever built or evaluated a predictive model, whether in a class, an internship, a competition, or a personal project? Briefly describe what you did and what you learned from it.
#
# 3. **Goals.** What do you hope to gain from this Predictive Analytics course?
#
# ---

# %% [markdown]
# ## 🗺️ Course Map and Notation
#
# Every notebook in this course carries a short code in the form **`nbXX`** where `XX` is its two-digit number, zero-padded. This notebook is `nb00`, the first content notebook is `nb01`, and the last notebook in the arc is `nb19`. When you see a phrase like *"nb08 introduced the cross-validation framework"* inside a later notebook, a Gemini prompt, or a video, it points to the notebook whose filename begins with `nb08_`.
#
# ### The semester arc at a glance
#
# ```
# ORIENTATION
#   nb00  Launchpad
#
# REGRESSION ARC
#   nb01 → nb02 → nb03 → nb04 → nb05
#   EDA    Pipelines Metrics Features Regularization
#
# CLASSIFICATION ARC
#   nb06 → nb07 → nb08 → nb09
#   LogReg Metrics  CV      Tuning
#
# ENSEMBLES + SELECTION ARC
#   nb11 → nb12 → nb13 → nb14
#   Trees  Forests Boosting Selection
#
# SPECIAL TOPICS + COURSE DELIVERIES
#   nb16 → nb17 → nb18 → nb19
#   TimeSeries Poster  Compete DeepLearn
# ```
#
# ### How the course is organized into modules
#
# That arc is the order you work through the material; the modules below are how Brightspace files it, and that is how you will find every notebook, slide deck, and assignment there.
#
# | Module | Notebooks | What it covers |
# |---|---|---|
# | **Module 0: Pre-course Launchpad** | `nb00` | Platform setup (Colab, Gemini), the syllabus, and how the course runs |
# | **Module 1: Foundations & Regression** | `nb01`–`nb05` | EDA, splits, preprocessing pipelines, regression metrics and baselines, feature engineering and diagnostics, Ridge/Lasso regularization |
# | **Module 2: Classification & Cross-Validation** | `nb06`–`nb09` | Logistic regression, classification metrics and cost-based thresholds, k-fold CV and paired model comparison, hyperparameter tuning and leakage detection |
# | **Module 3: Trees, Ensembles & Model Selection** | `nb11`–`nb14` | Decision trees, random forests and feature importance, gradient boosting, the model-selection protocol and the locked-test-set ceremony |
# | **Module 4: Special Topics and Course Deliveries** | `nb16`–`nb19` | Special topics (time-series forecasting and deep learning) alongside the two graded deliveries: data communication and poster design, and the Kaggle competition workflow |
# | **Module 5: Poster-to-Product** | none | The post-conference build sprint: turn your poster into a deployed dashboard or app plus an executive brief, with partner checkpoints and the final showcase |
#
# Module 5 lists no notebook because the Poster-to-Product sprint is build work on your own project rather than new notebook material.
#
# ### How your week runs
#
# **Monday and Wednesday carry the notebook content.** That is when a new `nbXX` is introduced and worked through together. **Every Friday is a group work session** for your final project and the Kaggle course case competition: working time on the two deliverables that carry most of your grade.
#
# Two Fridays step out of that rhythm. One early in the term carries a notebook, so the regression arc lands on schedule. Another hosts the **in-class Midterm Exam**, written on paper during class time, covering everything from `nb00` through `nb09`. Brightspace tells you which Fridays those are. Every remaining Friday is group work start to finish, with no new notebook.
#
# ### Full 18-notebook arc
#
# The arc runs `nb00`–`nb09`, `nb11`–`nb14`, and `nb16`–`nb19`. There is no `nb10`, `nb15`, or `nb20` this term, so a gap in the numbering is not a missing notebook.
#
# | Code | Title | Module | One-line focus |
# |---|---|---|---|
# | `nb00` | Launchpad: Course Setup | 0 | Platform, Gemini, course logistics (you are here) |
# | `nb01` | EDA & Splits | 1 | 60/20/20 train/val/test split; leakage vocabulary |
# | `nb02` | Preprocessing Pipelines | 1 | `Pipeline`, `ColumnTransformer`, imputation, scaling |
# | `nb03` | Regression Metrics & Baselines | 1 | MAE, RMSE, R²; `DummyRegressor` as a reference floor |
# | `nb04` | Linear Features & Diagnostics | 1 | Interactions, polynomials, residual plots |
# | `nb05` | Regularization + Project Proposal | 1 | Ridge / Lasso as a guard against overfit coefficients |
# | `nb06` | Logistic Regression & Pipelines | 2 | Binary classification with predicted probabilities |
# | `nb07` | Classification Metrics & Thresholds | 2 | Confusion matrix, ROC-AUC, cost-based threshold tuning |
# | `nb08` | Cross-Validation & Model Comparison | 2 | $k$-fold CV + descriptive fold intervals; paired per-fold model comparison |
# | `nb09` | Tuning + Feature Engineering + Leakage | 2 | `GridSearchCV`, `ColumnTransformer`, leakage case studies |
# | `nb11` | Decision Trees | 3 | CART, depth control, `class_weight='balanced'` |
# | `nb12` | Random Forests & Importance | 3 | Bagging, impurity vs. permutation importance |
# | `nb13` | Gradient Boosting | 3 | Sequential ensemble, early stopping, leakage amplification |
# | `nb14` | Model Selection + Test-Set Ceremony | 3 | Comparison harness + opening the locked test set |
# | `nb16` | Time-Series Forecasting | 4 | Walk-forward CV, lag features, baseline forecasters |
# | `nb17` | Data Communication & Poster Design | 4 | Six principles applied to the 11-section research-poster architecture |
# | `nb18` | Competition Workflow | 4 | End-to-end pipeline from notebook to Kaggle submission |
# | `nb19` | Special Topic: Deep Learning | 4 | PyTorch network trained end to end, a real LLM lab, and the four-question when-to-use rubric |
#
# Every notebook's filename on GitHub starts with its `nbXX` code. For example, `nb08_cross_validation_model_comparison_student.ipynb` is the file behind every `nb08` reference you will encounter.
#
# ---

# %% [markdown]
# ## 2. Course Syllabus and Logistics
#
# Read the **course syllabus** in the course Brightspace page (and the syllabus document linked there) before our first synchronous session.
#
# Brightspace is the authoritative source for grade weights, due dates, and course policy. It also carries the session-by-session calendar: what is taught each day, which sessions carry a quiz, and when each project milestone is due. Anything that shifts during the term is posted there, so when you need a date, check Brightspace rather than your memory of the first week.
#
# 📘 **Course website:** <https://davi-moreira.github.io/2026F_predictive_analytics_QM474/>
#
# ---

# %% [markdown]
# ## 3. Finding Your Group in Brightspace
#
# Most of the graded work in this course is done with a team. The final project runs from the first proposal all the way through the poster, and the course case competition is a team effort on Kaggle. Brightspace is where that team lives: it is how you see who your teammates are, how you reach them, and how your group deliverables get submitted.
#
# ### 3.1 How to get there
#
# 1. Open this course in Brightspace.
# 2. In the course navigation bar, select **Course Tools**, then choose **Groups** from the dropdown menu.
# 3. If you have already been assigned to a group, it is listed under **My Groups**, and there is nothing else to do.
# 4. If the course is set up for self-enrollment, click **View Available Groups**, find the group you want, and click the blue **Join Group** link. Once you join, that group moves into your **My Groups** section.
#
# The official Purdue instructions, with screenshots, are here: <https://www.purdue.edu/brightspace/Docs/LearnerResources/AccessBrightspaceGroups.php>
#
# ### 3.2 What the group area gives you
#
# Exactly which features appear depends on how a given group is configured, but you can generally expect:
#
# | Feature | What it is for |
# |---|---|
# | **Group Members** | See who else is on your team |
# | **Group Assignments** | Submit the deliverables your team turns in together |
# | **Group Discussions** | A conversation space only your group can see |
# | **Group Lockers** | Shared file storage for drafts, data, and slides |
# | **Email Group Members** | Reach your whole team without collecting addresses by hand |
# | **Leave Group** | Withdraw from a group you joined through self-enrollment |
#
# ---

# %% [markdown]
# ### 3.3 Do this before our next session
#
# Open **Groups**, confirm you are in one, and post a short hello in your group discussion so you know the channel works. Two things are worth knowing before you do.
#
# **A group assignment does not appear in your gradebook until you are enrolled in a group.** If you are not in one, the submission folder your teammates can see may not be visible to you at all. That is not a bug, and it is not a reason to wait and see. It is the signal to fix your enrollment.
#
# **Leaving a group is not a neutral act.** If you self-enroll into the wrong group, fix it right away, while teams are still forming. Once deliverables are underway, moving between teams costs your former teammates real work.
#
# > **A question that often comes up here:** *"I opened Groups and the page is empty. Did I do something wrong?"* Almost certainly not. An empty Groups page usually means one of three things: (1) enrollment is not open yet, so there is nothing to see until it is, (2) teams have been assigned but not yet published, or (3) you are looking at a different course, which is easy to do in a semester with several team-based classes. Check the course title at the top of the page first, then look again after the next class session. If it is still empty and your classmates can see their groups, email me a screenshot and I will sort out the enrollment on my end.
#
# ---

# %% [markdown]
# ## 4. Google Colab Setup and Notebook Conventions
#
# ### 4.1 Why Google Colab?
#
# **Google Colab** (Colaboratory) is a free, cloud-based Jupyter notebook environment that requires no local setup. It's perfect for this course because:
#
# - ✓ **Zero installation:** No Python setup, no package management, no environment conflicts
# - ✓ **Free GPU access:** Useful for deep learning later in the course
# - ✓ **Cloud storage:** Work from anywhere, automatic saves to Google Drive
# - ✓ **Built-in AI:** Google Gemini integration for coding assistance
# - ✓ **Reproducible:** Share notebooks via links, ensure everyone has the same environment
#
# **How to open this notebook in Colab:**
# 1. Click the "Open in Colab" badge you find at the course brightspace and webpage
# 2. Or visit: [https://colab.research.google.com/](https://colab.research.google.com/)
#
# ---

# %% [markdown]
# ### 4.2 Colab Navigation and Workflow
#
# **Notebook structure:**
# - **Markdown cells:** Text explanations (like this one). Double-click to edit, Shift+Enter to render.
# - **Code cells:** Python code that you can run. Click the play button or Shift+Enter to execute.
#
# **Essential keyboard shortcuts:**
# - **Shift + Enter:** Run cell and move to next
# - **Ctrl + Enter (Cmd + Enter on Mac):** Run cell and stay
# - **Ctrl + M B (Cmd + M B):** Insert cell below
# - **Ctrl + M A (Cmd + M A):** Insert cell above
# - **Ctrl + M D (Cmd + M D):** Delete cell
#
# **Menu options:**
# - **Runtime → Run all:** Execute all cells in order (use this to test reproducibility)
# - **Runtime → Restart runtime:** Clear all variables and outputs, start fresh
# - **File → Save a copy in Drive:** Create your own editable version
#
# **⚠️ Important:** Colab notebooks are **temporary** unless saved to your Drive. Always use "File → Save a copy in Drive" to preserve your work.
#
# ---

# %% [markdown]
# ### 4.3 Course Notebook Conventions
#
# Throughout this course, notebooks follow consistent patterns:
#
# **1. Setup Cell (always first code cell):**
# Every notebook starts with imports, random seed, and display settings.
#
# **2. RANDOM_SEED = 474:**
# We use seed 474 for all random operations to ensure reproducibility. This means every time you run the notebook, you'll get the same results.
#
# **3. PAUSE-AND-DO Exercises:**
# These are 10-minute guided practice sections where you'll apply concepts immediately. Look for this format:
#
# > ## 📝 PAUSE-AND-DO Exercise N (5 minutes)
# > **Task:** [What you need to do]
# > **Instructions:** [Step-by-step guidance]
#
# **4. Blockquotes for Critical Rules:**
# Important warnings and best practices appear like this:
#
# > ⚠️ **Critical Rule:** Always split data BEFORE preprocessing to avoid leakage.
#
# **5. ✓ Checkmarks for Confirmations:**
# When code completes successfully, you'll see: `✓ Setup complete!`
#
# **6. Comments in Code:**
# All code includes explanatory comments starting with `#` to help you understand each step.
#
# **7. Google Gemini Integration:**
# We'll use Gemini following the **"Ask → Verify → Document"** pattern (explained in Section 4.4).
#
# ---

# %% [markdown]
# ### 4.4 Using Google Gemini Responsibly: The "Ask → Verify → Document" Pattern
#
# **Google Gemini in Colab** is an AI coding assistant integrated directly into your notebooks. It can help you write code, debug errors, and understand concepts. However, **you are responsible for all code you submit**.
#
# **The Three-Step Pattern:**
#
# **1. ASK Gemini to draft code or explain concepts**
#
# Example prompts:
# - "Create a histogram of the MedHouseVal variable"
# - "Explain what this error message means: KeyError: 'MedHouseVal'"
# - "Write code to calculate the correlation between MedInc and MedHouseVal"
# - "Generate a scatter plot showing the relationship between Latitude and house values"
#
# **2. VERIFY the code works and you understand it**
# - Run the generated code in a cell
# - Check the output matches what you expected
# - Read through the code line by line
# - Ask yourself: "Could I explain what each line does?"
#
# **3. DOCUMENT with your own comments**
# - Add `#` comments explaining the logic in your own words
# - Annotate any parts that were unclear
# - Note any modifications you made
#
# **✓ What's allowed:**
# - Using Gemini to generate boilerplate code (imports, data loading, standard plots)
# - Asking Gemini to explain error messages or debugging
# - Getting suggestions for visualizations or analyses
# - Learning new pandas/numpy/sklearn functions
#
# **⚠️ What's required:**
# - You must understand **every line** of code you submit
# - You must verify that generated code works correctly on your data
# - You must add your own comments and documentation
# - You must be able to explain your code and methodology
#
# **❌ Accountability:**
# - You are responsible for all code you submit, even if Gemini generated it
# - If you can't explain your code in the project presentation, you don't understand it well enough
# - Gemini can make mistakes - you need to catch them
#
# **Example of proper use with California Housing data:**
#
# ```python
# # PROMPT TO GEMINI: "Calculate the mean MedHouseVal for coastal vs inland areas"
#
# # Original Gemini output (verified and commented by me):
# # Create a binary coastal indicator (Latitude > 37 and Longitude < -120)
# df['IsCoastal'] = ((df['Latitude'] > 37) & (df['Longitude'] < -120)).astype(int)
#
# # Group by coastal status and calculate mean house value
# mean_price_by_location = df.groupby('IsCoastal')['MedHouseVal'].mean()
#
# # Add my own descriptive print statement
# print("Average median house value by location:")
# print(f"  Inland (0): {mean_price_by_location[0]:.2f} (in $100,000s)")
# print(f"  Coastal (1): {mean_price_by_location[1]:.2f} (in $100,000s)")
#
# # My interpretation: Coastal areas have significantly higher median house values,
# # which makes sense given proximity to ocean and desirable California locations.
# ```
#
# **Why this matters:** AI tools like Gemini are powerful accelerators, but they don't replace understanding. In business, you need to explain your analyses to stakeholders, defend your methodology, and catch errors. Blindly trusting AI outputs is risky.
#
# ---

# %% [markdown]
# ### 4.5 Let's Test Your Setup
#
# Run the cell below to verify your Colab environment is ready. You should see:
# - Python version
# - Library versions
# - A simple plot
# - ✓ Setup confirmation
#
# If you see any errors, use Gemini to help debug!

# %%
# Setup Test Cell
# This cell verifies your Colab environment is properly configured

# Import essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import sklearn
import sys
import warnings

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')

# Set random seed for reproducibility
RANDOM_SEED = 474
np.random.seed(RANDOM_SEED)

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 3)
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

# Version check
print("=== ENVIRONMENT CHECK ===")
print(f"Python version: {sys.version.split()[0]}")
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"matplotlib: {plt.matplotlib.__version__}")
print(f"seaborn: {sns.__version__}")
print(f"scikit-learn: {sklearn.__version__}")

# Create a simple test plot
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(0, 0.1, 100)

plt.figure(figsize=(8, 4))
plt.plot(x, y, 'o', alpha=0.5, label='Noisy sine wave')
plt.plot(x, np.sin(x), 'r-', linewidth=2, label='True function')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Test Plot: If you see this, your environment works!')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

print("\n✓ Setup complete! Your Colab environment is ready.")
print(f"✓ Random seed set to {RANDOM_SEED} for reproducibility")
# Out:
# === ENVIRONMENT CHECK ===
# Python version: 3.11.13
# pandas: 3.0.0
# numpy: 2.4.2
# matplotlib: 3.10.8
# seaborn: 0.13.2
# scikit-learn: 1.8.0
# ✓ Setup complete! Your Colab environment is ready.
# ✓ Random seed set to 474 for reproducibility

# %% [markdown]
# ## 5. Wrap-Up: You're Ready!
#
# ### What We Covered:
#
# 1. **Course Overview**: The notebook arc, how the modules are organized, and the weekly rhythm
# 2. **Your Group in Brightspace**: Where to find your team, what the group area gives you, and why enrollment matters
# 3. **Google Colab**: Navigation, keyboard shortcuts, saving, and runtime management
# 4. **Notebook Conventions**: Setup cells, random seed 474, PAUSE-AND-DO exercises, and checkmarks
# 5. **Gemini Discipline**: The Ask → Verify → Document pattern for responsible AI-assisted coding
# 6. **Environment Verified**: Your Colab setup is confirmed working
#
# ### Next Step:
#
# You are now ready for **the first content notebook on Predictive Analytics Fundamentals, EDA, and Data Splitting**, where we dive into the substance: what predictive analytics is, how to explore data, and how to split it properly.
#
# ### Remember:
#
# > **"Use Gemini responsibly: Ask → Verify → Document. You own all code you submit."**
#
# ---

# %% [markdown]
# ## 6. Participation Assignment Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Complete the exercise**: Fill in the PAUSE-AND-DO exercise cell with your introduction
# 2. **Run All Cells**: Execute `Runtime → Run all` to ensure everything works
# 3. **Save a Copy**: `File → Save a copy in Drive or Download the .ipynb extension`
# 4. **Submit**: Upload your `.ipynb` file in the participation assignment you find in the course Brightspace page.
#
# ### Before Submitting, Check:
#
# - [ ] All cells execute without errors
# - [ ] All outputs are visible
# - [ ] Your introduction exercise is complete
# - [ ] You can explain every line of code you wrote
#
# ### Next Step:
#
# Complete the **Quiz** in Brightspace (auto-graded)
#
# ---
#
# ## Bibliography
#
# - Google Colab Documentation: https://colab.research.google.com/
# - Google Gemini in Colab: https://blog.google/technology/ai/google-gemini-update-flash-ai-assistant-io-2024/
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>
